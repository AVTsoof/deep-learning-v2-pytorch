# %% [markdown]
# # @AVTsoof: Download & Setup datasets

# %%
# @AVTsoof: Download datasets
# !wget -nc -P "/home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/" "https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/lfw.zip"
# !wget -nc -P "/home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/" "https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip"
# Out:
# File ‘/home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/lfw.zip’ already there; not retrieving.
#
# File ‘/home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/dogImages.zip’ already there; not retrieving.

# %%
# @AVTsoof: unzip datasets
# !unzip -n "/home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/lfw.zip" -d "/home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/"
# !unzip -n "/home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/dogImages.zip" -d "/home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/dogImages"
# Out:
# Archive:  /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/lfw.zip
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._.DS_Store
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Eckhart/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Eckhart/._Aaron_Eckhart_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Aaron_Eckhart
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Guiel/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Guiel/._Aaron_Guiel_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Aaron_Guiel
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Patterson/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Patterson/._Aaron_Patterson_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Aaron_Patterson
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Peirsol/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Peirsol/._Aaron_Peirsol_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Peirsol/._Aaron_Peirsol_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Peirsol/._Aaron_Peirsol_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Peirsol/._Aaron_Peirsol_0004.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Aaron_Peirsol
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Pena/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Pena/._Aaron_Pena_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Aaron_Pena
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Sorkin/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Sorkin/._Aaron_Sorkin_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Sorkin/._Aaron_Sorkin_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Aaron_Sorkin
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Tippin/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aaron_Tippin/._Aaron_Tippin_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Aaron_Tippin
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abba_Eban/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abba_Eban/._Abba_Eban_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abba_Eban
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abbas_Kiarostami/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abbas_Kiarostami/._Abbas_Kiarostami_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abbas_Kiarostami
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdel_Aziz_Al-Hakim/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdel_Aziz_Al-Hakim/._Abdel_Aziz_Al-Hakim_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abdel_Aziz_Al-Hakim
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdel_Madi_Shabneh/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdel_Madi_Shabneh/._Abdel_Madi_Shabneh_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abdel_Madi_Shabneh
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdel_Nasser_Assidi/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdel_Nasser_Assidi/._Abdel_Nasser_Assidi_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdel_Nasser_Assidi/._Abdel_Nasser_Assidi_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abdel_Nasser_Assidi
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdoulaye_Wade/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdoulaye_Wade/._Abdoulaye_Wade_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdoulaye_Wade/._Abdoulaye_Wade_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdoulaye_Wade/._Abdoulaye_Wade_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdoulaye_Wade/._Abdoulaye_Wade_0004.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abdoulaye_Wade
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdul_Majeed_Shobokshi/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdul_Majeed_Shobokshi/._Abdul_Majeed_Shobokshi_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abdul_Majeed_Shobokshi
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdul_Rahman/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdul_Rahman/._Abdul_Rahman_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abdul_Rahman
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdulaziz_Kamilov/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdulaziz_Kamilov/._Abdulaziz_Kamilov_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abdulaziz_Kamilov
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah/._Abdullah_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah/._Abdullah_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah/._Abdullah_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah/._Abdullah_0004.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abdullah
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Ahmad_Badawi/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Ahmad_Badawi/._Abdullah_Ahmad_Badawi_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abdullah_Ahmad_Badawi
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_al-Attiyah/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_al-Attiyah/._Abdullah_al-Attiyah_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_al-Attiyah/._Abdullah_al-Attiyah_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_al-Attiyah/._Abdullah_al-Attiyah_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abdullah_al-Attiyah
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0004.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0005.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0006.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0007.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0008.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0009.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0010.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0011.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0012.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0013.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0014.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0015.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0016.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0017.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0018.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Gul/._Abdullah_Gul_0019.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abdullah_Gul
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Nasseef/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullah_Nasseef/._Abdullah_Nasseef_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abdullah_Nasseef
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullatif_Sener/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullatif_Sener/._Abdullatif_Sener_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abdullatif_Sener/._Abdullatif_Sener_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abdullatif_Sener
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abel_Aguilar/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abel_Aguilar/._Abel_Aguilar_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abel_Aguilar
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abel_Pacheco/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abel_Pacheco/._Abel_Pacheco_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abel_Pacheco/._Abel_Pacheco_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abel_Pacheco/._Abel_Pacheco_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abel_Pacheco/._Abel_Pacheco_0004.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abel_Pacheco
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abid_Hamid_Mahmud_Al-Tikriti/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abid_Hamid_Mahmud_Al-Tikriti/._Abid_Hamid_Mahmud_Al-Tikriti_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abid_Hamid_Mahmud_Al-Tikriti/._Abid_Hamid_Mahmud_Al-Tikriti_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abid_Hamid_Mahmud_Al-Tikriti/._Abid_Hamid_Mahmud_Al-Tikriti_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abid_Hamid_Mahmud_Al-Tikriti
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abner_Martinez/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abner_Martinez/._Abner_Martinez_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abner_Martinez
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abraham_Foxman/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Abraham_Foxman/._Abraham_Foxman_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Abraham_Foxman
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aby_Har-Even/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aby_Har-Even/._Aby_Har-Even_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Aby_Har-Even
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Ant/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Ant/._Adam_Ant_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adam_Ant
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Freier/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Freier/._Adam_Freier_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adam_Freier
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Herbert/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Herbert/._Adam_Herbert_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adam_Herbert
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Kennedy/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Kennedy/._Adam_Kennedy_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adam_Kennedy
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Mair/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Mair/._Adam_Mair_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adam_Mair
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Rich/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Rich/._Adam_Rich_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adam_Rich
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Sandler/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Sandler/._Adam_Sandler_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Sandler/._Adam_Sandler_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Sandler/._Adam_Sandler_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Sandler/._Adam_Sandler_0004.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adam_Sandler
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Scott/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Scott/._Adam_Scott_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adam_Scott/._Adam_Scott_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adam_Scott
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adel_Al-Jubeir/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adel_Al-Jubeir/._Adel_Al-Jubeir_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adel_Al-Jubeir/._Adel_Al-Jubeir_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adel_Al-Jubeir/._Adel_Al-Jubeir_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adel_Al-Jubeir
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adelina_Avila/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adelina_Avila/._Adelina_Avila_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adelina_Avila
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adisai_Bodharamik/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adisai_Bodharamik/._Adisai_Bodharamik_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adisai_Bodharamik
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adolfo_Aguilar_Zinser/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adolfo_Aguilar_Zinser/._Adolfo_Aguilar_Zinser_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adolfo_Aguilar_Zinser/._Adolfo_Aguilar_Zinser_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adolfo_Aguilar_Zinser/._Adolfo_Aguilar_Zinser_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adolfo_Aguilar_Zinser
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adolfo_Rodriguez_Saa/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adolfo_Rodriguez_Saa/._Adolfo_Rodriguez_Saa_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adolfo_Rodriguez_Saa/._Adolfo_Rodriguez_Saa_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adolfo_Rodriguez_Saa
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adoor_Gopalakarishnan/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adoor_Gopalakarishnan/._Adoor_Gopalakarishnan_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adoor_Gopalakarishnan
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrian_Annus/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrian_Annus/._Adrian_Annus_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adrian_Annus
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrian_Fernandez/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrian_Fernandez/._Adrian_Fernandez_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adrian_Fernandez
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrian_McPherson/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrian_McPherson/._Adrian_McPherson_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrian_McPherson/._Adrian_McPherson_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adrian_McPherson
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrian_Murrell/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrian_Murrell/._Adrian_Murrell_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adrian_Murrell
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrian_Nastase/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrian_Nastase/._Adrian_Nastase_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrian_Nastase/._Adrian_Nastase_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adrian_Nastase
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adriana_Lima/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adriana_Lima/._Adriana_Lima_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adriana_Lima
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adriana_Perez_Navarro/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adriana_Perez_Navarro/._Adriana_Perez_Navarro_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adriana_Perez_Navarro
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrianna_Zuzic/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrianna_Zuzic/._Adrianna_Zuzic_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adrianna_Zuzic
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrien_Brody/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrien_Brody/._Adrien_Brody_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrien_Brody/._Adrien_Brody_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrien_Brody/._Adrien_Brody_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrien_Brody/._Adrien_Brody_0004.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrien_Brody/._Adrien_Brody_0005.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrien_Brody/._Adrien_Brody_0006.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrien_Brody/._Adrien_Brody_0007.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrien_Brody/._Adrien_Brody_0008.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrien_Brody/._Adrien_Brody_0009.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrien_Brody/._Adrien_Brody_0010.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrien_Brody/._Adrien_Brody_0011.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Adrien_Brody/._Adrien_Brody_0012.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Adrien_Brody
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Afton_Smith/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Afton_Smith/._Afton_Smith_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Afton_Smith
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Agbani_Darego/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Agbani_Darego/._Agbani_Darego_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Agbani_Darego
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Agnelo_Queiroz/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Agnelo_Queiroz/._Agnelo_Queiroz_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Agnelo_Queiroz
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Agnes_Bruckner/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Agnes_Bruckner/._Agnes_Bruckner_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Agnes_Bruckner
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmad_Jbarah/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmad_Jbarah/._Ahmad_Jbarah_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Ahmad_Jbarah
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmad_Masood/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmad_Masood/._Ahmad_Masood_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmad_Masood/._Ahmad_Masood_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Ahmad_Masood
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmed_Ahmed/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmed_Ahmed/._Ahmed_Ahmed_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Ahmed_Ahmed
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmed_Chalabi/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmed_Chalabi/._Ahmed_Chalabi_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmed_Chalabi/._Ahmed_Chalabi_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmed_Chalabi/._Ahmed_Chalabi_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmed_Chalabi/._Ahmed_Chalabi_0004.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmed_Chalabi/._Ahmed_Chalabi_0005.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Ahmed_Chalabi
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmed_Ghazi/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmed_Ghazi/._Ahmed_Ghazi_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Ahmed_Ghazi
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmed_Ibrahim_Bilal/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmed_Ibrahim_Bilal/._Ahmed_Ibrahim_Bilal_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Ahmed_Ibrahim_Bilal
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmed_Lopez/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmed_Lopez/._Ahmed_Lopez_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Ahmed_Lopez
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmed_Qureia/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmed_Qureia/._Ahmed_Qureia_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Ahmed_Qureia
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmet_Demir/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmet_Demir/._Ahmet_Demir_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Ahmet_Demir
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmet_Necdet_Sezer/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmet_Necdet_Sezer/._Ahmet_Necdet_Sezer_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ahmet_Necdet_Sezer/._Ahmet_Necdet_Sezer_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Ahmet_Necdet_Sezer
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ai_Sugiyama/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ai_Sugiyama/._Ai_Sugiyama_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ai_Sugiyama/._Ai_Sugiyama_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ai_Sugiyama/._Ai_Sugiyama_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ai_Sugiyama/._Ai_Sugiyama_0004.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ai_Sugiyama/._Ai_Sugiyama_0005.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Ai_Sugiyama
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aicha_El_Ouafi/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aicha_El_Ouafi/._Aicha_El_Ouafi_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aicha_El_Ouafi/._Aicha_El_Ouafi_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aicha_El_Ouafi/._Aicha_El_Ouafi_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Aicha_El_Ouafi
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aidan_Quinn/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aidan_Quinn/._Aidan_Quinn_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Aidan_Quinn
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aileen_Riggin_Soule/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aileen_Riggin_Soule/._Aileen_Riggin_Soule_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Aileen_Riggin_Soule
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ain_Seppik/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ain_Seppik/._Ain_Seppik_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Ain_Seppik
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ainsworth_Dyer/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ainsworth_Dyer/._Ainsworth_Dyer_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Ainsworth_Dyer
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aishwarya_Rai/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aishwarya_Rai/._Aishwarya_Rai_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Aishwarya_Rai
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aitor_Gonzalez/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aitor_Gonzalez/._Aitor_Gonzalez_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aitor_Gonzalez/._Aitor_Gonzalez_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Aitor_Gonzalez
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aiysha_Smith/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Aiysha_Smith/._Aiysha_Smith_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Aiysha_Smith
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/AJ_Cook/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/AJ_Cook/._AJ_Cook_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._AJ_Cook
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/AJ_Lamas/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/AJ_Lamas/._AJ_Lamas_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._AJ_Lamas
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ajit_Agarkar/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ajit_Agarkar/._Ajit_Agarkar_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Ajit_Agarkar
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Akbar_Al_Baker/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Akbar_Al_Baker/._Akbar_Al_Baker_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Akbar_Al_Baker
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Akbar_Hashemi_Rafsanjani/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Akbar_Hashemi_Rafsanjani/._Akbar_Hashemi_Rafsanjani_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Akbar_Hashemi_Rafsanjani/._Akbar_Hashemi_Rafsanjani_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Akbar_Hashemi_Rafsanjani/._Akbar_Hashemi_Rafsanjani_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Akbar_Hashemi_Rafsanjani
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Akhmed_Zakayev/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Akhmed_Zakayev/._Akhmed_Zakayev_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Akhmed_Zakayev/._Akhmed_Zakayev_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Akhmed_Zakayev/._Akhmed_Zakayev_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Akhmed_Zakayev
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Akiko_Morigami/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Akiko_Morigami/._Akiko_Morigami_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Akiko_Morigami
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Akmal_Taher/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Akmal_Taher/._Akmal_Taher_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Akmal_Taher
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Cardenas/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Cardenas/._Al_Cardenas_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Al_Cardenas
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Davis/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Davis/._Al_Davis_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Davis/._Al_Davis_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Al_Davis
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Gore/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Gore/._Al_Gore_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Gore/._Al_Gore_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Gore/._Al_Gore_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Gore/._Al_Gore_0004.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Gore/._Al_Gore_0005.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Gore/._Al_Gore_0006.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Gore/._Al_Gore_0007.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Gore/._Al_Gore_0008.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Al_Gore
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Leiter/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Leiter/._Al_Leiter_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Al_Leiter
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Pacino/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Pacino/._Al_Pacino_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Pacino/._Al_Pacino_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Pacino/._Al_Pacino_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Al_Pacino
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Sharpton/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Sharpton/._Al_Sharpton_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Sharpton/._Al_Sharpton_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Sharpton/._Al_Sharpton_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Sharpton/._Al_Sharpton_0004.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Sharpton/._Al_Sharpton_0005.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Sharpton/._Al_Sharpton_0006.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Al_Sharpton/._Al_Sharpton_0007.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Al_Sharpton
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Alain_Cervantes/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Alain_Cervantes/._Alain_Cervantes_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Alain_Cervantes
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Alain_Ducasse/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Alain_Ducasse/._Alain_Ducasse_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Alain_Ducasse
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Alan_Ball/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Alan_Ball/._Alan_Ball_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Alan_Ball/._Alan_Ball_0002.jpg
# ...
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Yusuf_Misbac/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Yusuf_Misbac/._Yusuf_Misbac_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Yusuf_Misbac
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Yuvraj_Singh/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Yuvraj_Singh/._Yuvraj_Singh_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Yuvraj_Singh
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Yves_Brodeur/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Yves_Brodeur/._Yves_Brodeur_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Yves_Brodeur
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zach_Parise/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zach_Parise/._Zach_Parise_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zach_Parise
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zach_Pillar/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zach_Pillar/._Zach_Pillar_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zach_Pillar
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zach_Safrin/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zach_Safrin/._Zach_Safrin_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zach_Safrin
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zafarullah_Khan_Jamali/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zafarullah_Khan_Jamali/._Zafarullah_Khan_Jamali_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zafarullah_Khan_Jamali/._Zafarullah_Khan_Jamali_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zafarullah_Khan_Jamali
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zahir_Shah/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zahir_Shah/._Zahir_Shah_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zahir_Shah
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zaini_Abdullah/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zaini_Abdullah/._Zaini_Abdullah_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zaini_Abdullah
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zakia_Hakki/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zakia_Hakki/._Zakia_Hakki_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zakia_Hakki
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zalmay_Khalilzad/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zalmay_Khalilzad/._Zalmay_Khalilzad_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zalmay_Khalilzad
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zara_Akhmadova/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zara_Akhmadova/._Zara_Akhmadova_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zara_Akhmadova
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zarai_Toledo/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zarai_Toledo/._Zarai_Toledo_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zarai_Toledo/._Zarai_Toledo_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zarai_Toledo
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zavad_Zarif/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zavad_Zarif/._Zavad_Zarif_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zavad_Zarif
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zdravko_Mucic/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zdravko_Mucic/._Zdravko_Mucic_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zdravko_Mucic
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zeljko_Rebraca/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zeljko_Rebraca/._Zeljko_Rebraca_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zeljko_Rebraca
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zelma_Novelo/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zelma_Novelo/._Zelma_Novelo_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zelma_Novelo
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zeng_Qinghong/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zeng_Qinghong/._Zeng_Qinghong_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zeng_Qinghong
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhang_Wenkang/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhang_Wenkang/._Zhang_Wenkang_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhang_Wenkang/._Zhang_Wenkang_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zhang_Wenkang
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhang_Yimou/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhang_Yimou/._Zhang_Yimou_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zhang_Yimou
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhang_Ziyi/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhang_Ziyi/._Zhang_Ziyi_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhang_Ziyi/._Zhang_Ziyi_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhang_Ziyi/._Zhang_Ziyi_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhang_Ziyi/._Zhang_Ziyi_0004.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zhang_Ziyi
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhong_Nanshan/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhong_Nanshan/._Zhong_Nanshan_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zhong_Nanshan
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhu_Rongji/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhu_Rongji/._Zhu_Rongji_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhu_Rongji/._Zhu_Rongji_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhu_Rongji/._Zhu_Rongji_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhu_Rongji/._Zhu_Rongji_0004.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhu_Rongji/._Zhu_Rongji_0005.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhu_Rongji/._Zhu_Rongji_0006.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhu_Rongji/._Zhu_Rongji_0007.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhu_Rongji/._Zhu_Rongji_0008.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zhu_Rongji/._Zhu_Rongji_0009.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zhu_Rongji
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zico/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zico/._Zico_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zico/._Zico_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zico/._Zico_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zico
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zinedine_Zidane/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zinedine_Zidane/._Zinedine_Zidane_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zinedine_Zidane/._Zinedine_Zidane_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zinedine_Zidane/._Zinedine_Zidane_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zinedine_Zidane/._Zinedine_Zidane_0004.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zinedine_Zidane/._Zinedine_Zidane_0005.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zinedine_Zidane/._Zinedine_Zidane_0006.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zinedine_Zidane
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ziwang_Xu/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Ziwang_Xu/._Ziwang_Xu_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Ziwang_Xu
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zoe_Ball/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zoe_Ball/._Zoe_Ball_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zoe_Ball
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zoran_Djindjic/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zoran_Djindjic/._Zoran_Djindjic_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zoran_Djindjic/._Zoran_Djindjic_0002.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zoran_Djindjic/._Zoran_Djindjic_0003.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zoran_Djindjic/._Zoran_Djindjic_0004.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zoran_Djindjic
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zorica_Radovic/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zorica_Radovic/._Zorica_Radovic_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zorica_Radovic
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zulfiqar_Ahmed/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zulfiqar_Ahmed/._Zulfiqar_Ahmed_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zulfiqar_Ahmed
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zumrati_Juma/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zumrati_Juma/._Zumrati_Juma_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zumrati_Juma
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zurab_Tsereteli/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zurab_Tsereteli/._Zurab_Tsereteli_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zurab_Tsereteli
#    creating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zydrunas_Ilgauskas/
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/Zydrunas_Ilgauskas/._Zydrunas_Ilgauskas_0001.jpg
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/lfw/._Zydrunas_Ilgauskas
#   inflating: /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX/._lfw
# Archive:  /home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/dogImages.zip

# %%
# @AVTsoof: remove unneeded folder
# !rm -r "/home/lubuntu/Projects/deep-learning-v2-pytorch/project-dog-classification/__MACOSX"

# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the Jupyter Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this Jupyter notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Write your Algorithm
# * [Step 6](#step6): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# Make sure that you've downloaded the required human and dog datasets:
# * Download the [dog dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip).  Unzip the folder and place it in this project's home directory, at the location `/dogImages`.
#
# * Download the [human dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/lfw.zip).  Unzip the folder and place it in the home directory, at location `/lfw`.
#
# *Note: If you are using a Windows machine, you are encouraged to use [7zip](http://www.7-zip.org/) to extract the folder.*
#
# In the code cell below, we save the file paths for both the human (LFW) dataset and dog dataset in the numpy arrays `human_files` and `dog_files`.

# %%
import numpy as np
from glob import glob

# load filenames for human and dog images
human_files = np.array(glob("./lfw/*/*"))
dog_files = np.array(glob("./dogImages/*/*/*/*"))  # @AVTsoof: fixed

# print number of images in each dataset
print('There are %d total human images.' % len(human_files))
print('There are %d total dog images.' % len(dog_files))
# Out:
# There are 13233 total human images.
# There are 8351 total dog images.

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# In this section, we use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.
#
# OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.  In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

show_human_or_dog = True


# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
if show_human_or_dog:
    img = cv2.imread(human_files[0])
else:
    img = cv2.imread(dog_files[0])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.

# %% [markdown]
# __Answer:__
# (You can print out your results and/or write your percentages in this cell)

# %%
from tqdm import tqdm

human_files_short = human_files[:100]
dog_files_short = dog_files[:100]

#-#-# Do NOT modify the code above this line. #-#-#

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
n_detected_humans_in_human_files = 0.0
n_detected_humans_in_dog_files = 0.0

for h in human_files_short:
    n_detected_humans_in_human_files += face_detector(h)

for d in dog_files_short:
    n_detected_humans_in_dog_files += face_detector(d)

human_accuracy = 100*n_detected_humans_in_human_files/len(human_files_short)
dog_accuracy = 100*n_detected_humans_in_dog_files/len(dog_files_short)

print(f"Human dataset : {human_accuracy:.2f} % humans detected")
print(f"Dog dataset   : {dog_accuracy:.2f} % humans detected")
# Out:
# Human dataset : 100.00 % humans detected
# Dog dataset   : 9.00 % humans detected

# %% [markdown]
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Test performance of another face detection algorithm.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a [pre-trained model](http://pytorch.org/docs/master/torchvision/models.html) to detect dogs in images.
#
# ### Obtain Pre-trained VGG-16 Model
#
# The code cell below downloads the VGG-16 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
import torch
import torchvision.models as models

# define VGG16 model
VGG16 = models.vgg16(pretrained=True)

# check if CUDA is available
use_cuda = torch.cuda.is_available()

# move model to GPU if CUDA is available
if use_cuda:
    VGG16 = VGG16.cuda()

# %% [markdown]
# Given an image, this pre-trained VGG-16 model returns a prediction (derived from the 1000 possible categories in ImageNet) for the object that is contained in the image.

# %% [markdown]
# ### (IMPLEMENTATION) Making Predictions with a Pre-trained Model
#
# In the next code cell, you will write a function that accepts a path to an image (such as `'dogImages/train/001.Affenpinscher/Affenpinscher_00001.jpg'`) as input and returns the index corresponding to the ImageNet class that is predicted by the pre-trained VGG-16 model.  The output should always be an integer between 0 and 999, inclusive.
#
# Before writing the function, make sure that you take the time to learn  how to appropriately pre-process tensors for pre-trained models in the [PyTorch documentation](https://pytorch.org/vision/stable/models.html).

# %%
from PIL import Image
import torchvision.transforms as transforms

# Set PIL to be tolerant of image files that are truncated.
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

def VGG16_predict(img_path):
    '''
    Use pre-trained VGG-16 model to obtain index corresponding to 
    predicted ImageNet class for image at specified path
    
    Args:
        img_path: path to an image
        
    Returns:
        Index corresponding to VGG-16 model's prediction
    '''
    
    ## TODO: Complete the function.
    ## Load and pre-process an image from the given img_path
    img = Image.open(img_path).convert('RGB')
    in_transform = transforms.Compose([
        transforms.Resize(224),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))  # normalize according to pytorch documentation
        ])
    # discard the transparent, alpha channel (that's the :3) and add the batch dimension
    img = in_transform(img)[:3,:,:].unsqueeze(0)

    ## Return the *index* of the predicted class for that image
    pred = torch.argmax(VGG16(img)).item()
    
    return pred

# %% [markdown]
# ### (IMPLEMENTATION) Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained VGG-16 model, we need only check if the pre-trained model predicts an index between 151 and 268 (inclusive).
#
# Use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    ## TODO: Complete the function.
    pred = VGG16_predict(img_path)
    return 151 <= pred <= 268 # true/false

# %%
# @AVTsoof: test VGG16_predict and dog_detector
with open("imagenet1000_clsidx_to_labels.txt") as f:
    idx2label = eval(f.read())

dog_file = dog_files[100]
pred = VGG16_predict(dog_file)
is_dog = dog_detector(dog_file)
print(f"{idx2label[pred]} - is a dog? {is_dog}")
# Out:
# Irish water spaniel - is a dog? True

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 2:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?

# %% [markdown]
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.
n_dogs_detected_in_human_files = 0.0
n_dogs_detected_in_dog_files = 0.0

for h in human_files_short:
    n_dogs_detected_in_human_files += dog_detector(h)

for d in dog_files_short:
    n_dogs_detected_in_dog_files += dog_detector(d)

human_accuracy = 100*n_dogs_detected_in_human_files/len(human_files_short)
dog_accuracy = 100*n_dogs_detected_in_dog_files/len(dog_files_short)

print(f"Human dataset : {human_accuracy:.2f} % dogs detected")
print(f"Dog dataset   : {dog_accuracy:.2f} % dogs detected")
# Out:
# Human dataset : 1.00 % dogs detected
# Dog dataset   : 100.00 % dogs detected

# %% [markdown]
# We suggest VGG-16 as a potential network to detect dog images in your algorithm, but you are free to explore other pre-trained networks (such as [Inception-v3](http://pytorch.org/docs/master/torchvision/models.html#inception-v3), [ResNet-50](http://pytorch.org/docs/master/torchvision/models.html#id3), etc).  Please use the code cell below to test other pre-trained PyTorch models.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Report the performance of another pre-trained network.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 10%.  In Step 4 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have trouble distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dogImages/train`, `dogImages/valid`, and `dogImages/test`, respectively).  You may find [this documentation on custom datasets](http://pytorch.org/docs/stable/torchvision/datasets.html) to be a useful resource.  If you are interested in augmenting your training and/or validation data, check out the wide variety of [transforms](http://pytorch.org/docs/stable/torchvision/transforms.html?highlight=transform)!

# %%
import os
from torchvision import datasets

### TODO: Write data loaders for training, validation, and test sets
## Specify appropriate transforms, and batch_sizes

# %% [markdown]
# **Question 3:** Describe your chosen procedure for preprocessing the data.
# - How does your code resize the images (by cropping, stretching, etc)?  What size did you pick for the input tensor, and why?
# - Did you decide to augment the dataset?  If so, how (through translations, flips, rotations, etc)?  If not, why not?

# %% [markdown]
# **Answer**:

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  Use the template in the code cell below.

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architecture
class Net(nn.Module):
    ### TODO: choose an architecture, and complete the class
    def __init__(self):
        super(Net, self).__init__()
        ## Define layers of a CNN
    
    def forward(self, x):
        ## Define forward behavior
        return x

#-#-# You do NOT have to modify the code below this line. #-#-#

# instantiate the CNN
model_scratch = Net()

# move tensors to GPU if CUDA is available
if use_cuda:
    model_scratch.cuda()

# %% [markdown]
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.

# %% [markdown]
# __Answer:__

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/stable/optim.html).  Save the chosen loss function as `criterion_scratch`, and the optimizer as `optimizer_scratch` below.

# %%
import torch.optim as optim

### TODO: select loss function
criterion_scratch = None

### TODO: select optimizer
optimizer_scratch = None

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_scratch.pt'`.

# %%
# the following import is required for training to be robust to truncated images
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
        ######################    
        # validate the model #
        ######################
        model.eval()
        for batch_idx, (data, target) in enumerate(loaders['valid']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## update the average validation loss

            
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
            epoch, 
            train_loss,
            valid_loss
            ))
        
        ## TODO: save the model if validation loss has decreased
            
    # return trained model
    return model


# train the model
model_scratch = train(100, loaders_scratch, model_scratch, optimizer_scratch, 
                      criterion_scratch, use_cuda, 'model_scratch.pt')

# load the model that got the best validation accuracy
model_scratch.load_state_dict(torch.load('model_scratch.pt'))

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images.  Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 10%.

# %%
def test(loaders, model, criterion, use_cuda):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    for batch_idx, (data, target) in enumerate(loaders['test']):
        # move to GPU
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# call test function    
test(loaders_scratch, model_scratch, criterion_scratch, use_cuda)

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dogImages/train`, `dogImages/valid`, and `dogImages/test`, respectively).
#
# If you like, **you are welcome to use the same data loaders from the previous step**, when you created a CNN from scratch.

# %%
## TODO: Specify data loaders

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Use transfer learning to create a CNN to classify dog breed.  Use the code cell below, and save your initialized model as the variable `model_transfer`.

# %%
import torchvision.models as models
import torch.nn as nn

## TODO: Specify model architecture 


if use_cuda:
    model_transfer = model_transfer.cuda()

# %% [markdown]
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.

# %% [markdown]
# __Answer:__

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/master/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/master/optim.html).  Save the chosen loss function as `criterion_transfer`, and the optimizer as `optimizer_transfer` below.

# %%
criterion_transfer = None
optimizer_transfer = None

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_transfer.pt'`.

# %%
# train the model
model_transfer = # train(n_epochs, loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer, use_cuda, 'model_transfer.pt')

# load the model that got the best validation accuracy (uncomment the line below)
#model_transfer.load_state_dict(torch.load('model_transfer.pt'))

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 60%.

# %%
test(loaders_transfer, model_transfer, criterion_transfer, use_cuda)

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan hound`, etc) that is predicted by your model.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

# list of class names by index, i.e. a name can be accessed like class_names[0]
class_names = [item[4:].replace("_", " ") for item in data_transfer['train'].classes]

def predict_breed_transfer(img_path):
    # load the image and return the predicted breed
    return None

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 4 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.

def run_app(img_path):
    ## handle cases for a human face, dog, and neither

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that _you_ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.

# %% [markdown]
# __Answer:__ (Three possible points for improvement)

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

## suggested code, below
for file in np.hstack((human_files[:3], dog_files[:3])):
    run_app(file)
